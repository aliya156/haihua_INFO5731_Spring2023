# %% [markdown]
# <a href="https://colab.research.google.com/github/aliya156/haihua_INFO5731_Spring2023/blob/main/In_class_exercise_03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## The third In-class-exercise (2/28/2023, 40 points in total)

# %% [markdown]
# The purpose of this exercise is to understand text representation.

# %% [markdown]
# Question 1 (10 points): Describe an interesting text classification or text mining task and explain what kind of features might be useful for you to build the machine learning model. List your features and explain why these features might be helpful. You need to list at least five different types of features.

# %%
# Your answer here (no code for this question, write down your answer as detail as possible for the above questions):

'''
1. Word frequency: The frequency of certain words in the movie review could be used as a feature. For example, positive reviews may contain words like "excellent", "amazing", and "fantastic" more frequently than negative reviews.

2. Parts of speech: The parts of speech of words in the movie review could be used as features. For example, adjectives may be more prevalent in positive reviews than negative ones.

3. Negation: Negation can be used as a feature as it can change the meaning of a sentence. For example, "The acting was not good" has a negative sentiment whereas "The acting was good" has a positive sentiment.

4. Length of the review: The length of the review could be used as a feature. Longer reviews may contain more information and could be more informative in determining the sentiment of the review.

5. Punctuation: The use of punctuation, such as exclamation marks and question marks, could be used as features. For example, positive reviews may contain more exclamation marks than negative reviews.


'''
# Out:
# '\n1. Word frequency: The frequency of certain words in the movie review could be used as a feature. For example, positive reviews may contain words like "excellent", "amazing", and "fantastic" more frequently than negative reviews.\n\n2. Parts of speech: The parts of speech of words in the movie review could be used as features. For example, adjectives may be more prevalent in positive reviews than negative ones.\n\n3. Negation: Negation can be used as a feature as it can change the meaning of a sentence. For example, "The acting was not good" has a negative sentiment whereas "The acting was good" has a positive sentiment.\n\n4. Length of the review: The length of the review could be used as a feature. Longer reviews may contain more information and could be more informative in determining the sentiment of the review.\n\n5. Punctuation: The use of punctuation, such as exclamation marks and question marks, could be used as features. For example, positive reviews may contain more excl
# ...

# %% [markdown]
# Question 2 (10 points): Write python code to extract these features you discussed above. You can collect a few sample text data for the feature extraction.

# %%
import nltk
nltk.download('all')
# Out:
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/abc.zip.
# [nltk_data]    | Downloading package alpino to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/alpino.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger_ru to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping
# [nltk_data]    |       taggers/averaged_perceptron_tagger_ru.zip.
# [nltk_data]    | Downloading package basque_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping grammars/basque_grammars.zip.
# [nltk_data]    | Downloading package bcp47 to /root/nltk_data...
# [nltk_data]    | Downloading package biocreative_ppi to
# ...

# %%
# You code here (Please add comments in the code):
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
import string

# Sample text data
text_data = "The acting was not good, but the cinematography was amazing. Overall, it was a fantastic movie!"

# Convert to lowercase
text_data = text_data.lower()

# Tokenize words
words = word_tokenize(text_data)

# Remove stopwords and punctuation
stopwords_list = stopwords.words('english') + list(string.punctuation)
words = [word for word in words if word not in stopwords_list]

# Lemmatize words
lemmatizer = WordNetLemmatizer()
words = [lemmatizer.lemmatize(word) for word in words]

# Word frequency feature
word_freq = {}
for word in words:
    if word not in word_freq:
        word_freq[word] = 1
    else:
        word_freq[word] += 1

# Parts of speech feature
pos_tags = nltk.pos_tag(words)
pos_counts = {}
for tag in pos_tags:
    if tag[1] not in pos_counts:
        pos_counts[tag[1]] = 1
    else:
        pos_counts[tag[1]] += 1

# Negation feature
negation_words = ['not', 'no', 'never', 'neither', 'nor', 'nobody', 'none']
has_negation = any(word in negation_words for word in words)

# Length of review feature
review_length = len(words)

# Punctuation feature
punctuation_counts = {}
for char in text_data:
    if char in string.punctuation:
        if char not in punctuation_counts:
            punctuation_counts[char] = 1
        else:
            punctuation_counts[char] += 1

print("Word frequency: ", word_freq)
print("Parts of speech: ", pos_counts)
print("Negation: ", has_negation)
print("Review length: ", review_length)
print("Punctuation counts: ", punctuation_counts)
# Out:
# Word frequency:  {'acting': 1, 'good': 1, 'cinematography': 1, 'amazing': 1, 'overall': 1, 'fantastic': 1, 'movie': 1}
# Parts of speech:  {'VBG': 2, 'JJ': 3, 'NN': 2}
# Negation:  False
# Review length:  7
# Punctuation counts:  {',': 2, '.': 1, '!': 1}

# %% [markdown]
# Question 3 (10 points): Use any of the feature selection methods mentioned in this paper "Deng, X., Li, Y., Weng, J., & Zhang, J. (2019). Feature selection for text classification: A review. Multimedia Tools & Applications, 78(3)." Select the most important features you extracted above, rank the features based on their importance in the descending order.

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_selection import mutual_info_classif
import string
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

# Sample text data
text_data = "The acting was not good, but the cinematography was amazing. Overall, it was a fantastic movie!"

# Convert to lowercase
text_data = text_data.lower()

# Tokenize words
words = word_tokenize(text_data)

# Remove stopwords and punctuation
stopwords_list = stopwords.words('english') + list(string.punctuation)
words = [word for word in words if word not in stopwords_list]

# Lemmatize words
lemmatizer = WordNetLemmatizer()
words = [lemmatizer.lemmatize(word) for word in words]

# Convert words to numeric values using CountVectorizer
vectorizer = CountVectorizer()
X = vectorizer.fit_transform([' '.join(words)])
feature_names = vectorizer.vocabulary_.keys()

# Calculate MI scores
y = ['positive']  # assuming this review is positive
mi_scores = mutual_info_classif(X, y)

# Print MI scores in descending order
sorted_features = sorted(zip(feature_names, mi_scores), key=lambda x: x[1], reverse=True)
for feature, score in sorted_features:
    print(f"{feature}: {score}")
# Out:
# acting: 0.0
# good: 0.0
# cinematography: 0.0
# amazing: 0.0
# overall: 0.0
# fantastic: 0.0
# movie: 0.0

# %% [markdown]
# Question 4 (10 points): Write python code to rank the text based on text similarity. Based on the text data you used for question 2, design a query to match the most relevant docments. Please use the BERT model to represent both your query and the text data, then calculate the cosine similarity between the query and each text in your data. Rank the similary with descending order.

# %%
# !pip install torch==1.8.0+cu101 torchvision==0.9.0+cu101 torchaudio===0.8.0 -f https://download.pytorch.org/whl/torch_stable.html
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Looking in links: https://download.pytorch.org/whl/torch_stable.html
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 763.6/763.6 MB 2.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 44.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 25.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: torch
#     Found existing installation: torch 1.13.1+cu116
#     Uninstalling torch-1.13.1+cu116:
#       Successfully uninstalled torch-1.13.1+cu116
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.14.1+cu116
#     Uninstalling torchvision-0.14.1+cu116:
#       Successfully uninstalled torchvision-0.14.1+cu116
#   Attempting uninstall: torchaudio
#     Found existing installation: torchaudio 0.13.1+cu116
#     Uninstalling torchaudio-0.13.1+cu116:
#       Successfully uninstalled torchaudio-0.13.1+cu116
# ...

# %%
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 41.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 61.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.2/199.2 KB 24.4 MB/s eta 0:00:00
# ...

# %%
# !pip install --upgrade packaging
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import numpy as np
import torch
from transformers import BertTokenizer, BertModel
from sklearn.metrics.pairwise import cosine_similarity

# Sample text data
text_data = ["This is a fantastic movie. I loved the acting and the cinematography.", 
             "The acting was not good, but the cinematography was amazing. Overall, it was a fantastic movie!",
             "I didn't like this movie at all. The plot was confusing and the acting was terrible."]

# Query to match the most relevant documents
query = "I enjoyed this movie. The acting was great and the cinematography was stunning."

# Load BERT model and tokenizer
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
model = BertModel.from_pretrained('bert-base-uncased')

# Tokenize and encode query
query_tokens = tokenizer.tokenize(query)
query_tokens = ['[CLS]'] + query_tokens + ['[SEP]']
query_ids = tokenizer.convert_tokens_to_ids(query_tokens)
query_tensor = torch.tensor(query_ids).unsqueeze(0)

# Get BERT embeddings for query
with torch.no_grad():
    query_outputs = model(query_tensor)
    query_embeddings = query_outputs[0][:, 0, :].numpy().reshape(1, -1)

# Tokenize, encode and get BERT embeddings for text data
text_embeddings = np.zeros((len(text_data), 768))
for i, text in enumerate(text_data):
    text_tokens = tokenizer.tokenize(text)
    text_tokens = ['[CLS]'] + text_tokens + ['[SEP]']
    text_ids = tokenizer.convert_tokens_to_ids(text_tokens)
    text_tensor = torch.tensor(text_ids).unsqueeze(0)
    
    with torch.no_grad():
        text_outputs = model(text_tensor)
        text_embedding = text_outputs[0][:, 0, :].numpy()
        text_embeddings[i] = text_embedding

# Calculate cosine similarity between query and each text in data
similarities = cosine_similarity(query_embeddings, text_embeddings)[0]

# Rank the similarities in descending order
ranked_similarities = np.argsort(similarities)[::-1]
for i in ranked_similarities:
    print(f"Text {i+1}: {text_data[i]}")
    print(f"Cosine similarity: {similarities[i]}")
# Out:
# ...
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertModel: ['cls.seq_relationship.weight', 'cls.predictions.decoder.weight', 'cls.predictions.transform.dense.weight', 'cls.predictions.bias', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Text 1: This is a fantastic movie. I loved the acting and the cinematography.
# Cosine similarity: 0.9744693599726777
# ...
