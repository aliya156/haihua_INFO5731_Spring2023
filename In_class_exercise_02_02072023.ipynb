# %% [markdown]
# <a href="https://colab.research.google.com/github/aliya156/haihua_INFO5731_Spring2023/blob/main/In_class_exercise_02_02072023.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## The second In-class-exercise (02/07/2023, 40 points in total)

# %% [markdown]
# The purpose of this exercise is to understand users' information needs, then collect data from different sources for analysis.

# %% [markdown]
# Question 1 (10 points): Describe an interesting research question (or practical question) you have in mind, what kind of data should be collected to answer the question(s)? How many data needed for the analysis? The detail steps for collecting and save the data.

# %%
# Your answer here (no code for this question, write down your answer as detail as possible for the above questions):

'''
Please write you answer here: (Answer can be found below in the text)
'''
# Out:
# '\nPlease write you answer here: (Answer can be found below in the text)\n'

# %% [markdown]
# In today's world, there are numerous apps. I therefore wanted to compile a list of every app and learn how to use them.
#  In order to print the findings, I gathered information from https://www.kaggle.com/search?q=googleplaystore+csv+in%3Adatasets.
#  To determine each app's effectiveness, we may also check its ratings and reviews.
# We have collected more than 1000 samples as shown below and the steps for collecting and saving the data are:
# 1. We have imported all the required libraries to code in python
# 2.The information is gathered from kaggle website.
# 3. We have run the code to print the desired information as shown below.
# 4. We can also find the ratings and reviews of each app listed below by running
#    the similar code.

# %% [markdown]
# Question 2 (10 points): Write python code to collect 1000 data samples you discussed above.

# %%
# You code here (Please add comments in the code):

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from google.colab import files
import io
data = files.upload()
# Out:
#      <input type="file" id="files-358d530e-4321-45f3-8552-5bd567881e8f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-358d530e-4321-45f3-8552-5bd567881e8f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df=pd.read_csv('googleplaystore.csv')
print(df[['App']])
# Out:
#                                                      App
# 0         Photo Editor & Candy Camera & Grid & ScrapBook
# 1                                    Coloring book moana
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...
# 3                                  Sketch - Draw & Paint
# 4                  Pixel Draw - Number Art Coloring Book
# ...                                                  ...
# 10836                                   Sya9a Maroc - FR
# 10837                   Fr. Mike Schmitz Audio Teachings
# 10838                             Parkinson Exercices FR
# 10839                      The SCP Foundation DB fr nn5n
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology
#
# [10841 rows x 1 columns]

# %% [markdown]
# We can also collect data using webscraping method using beautiful soup library as shown below. We have collected data using the url link shown below.

# %%
import pandas as pd
import numpy as np
import requests
import time
import re
from bs4 import BeautifulSoup

# %%
url = "https://www.imdb.com/india/top-rated-indian-movies/?pf_rd_m=A2FGELUUNOQJNL&pf_rd_p=470df400-70d9-4f35-bb05-8646a1195842&pf_rd_r=RYN02GNP5EQYDEAMGJ99&pf_rd_s=right-4&pf_rd_t=15506&pf_rd_i=topenglish&ref_=chttentp_ql_7"
page = requests.get(url)
page
soup = BeautifulSoup(page.content, "html.parser")

# %%
films = soup.find_all('td', class_='titleColumn')
films
# Out:
# [<td class="titleColumn">
#        1.
#        <a href="/title/tt0259534/" title="Ram Mohan (dir.), Bryan Cranston, Arun Govil">Ramayana: The Legend of Prince Rama</a>
#  <span class="secondaryInfo">(1993)</span>
#  </td>, <td class="titleColumn">
#        2.
#        <a href="/title/tt9263550/" title="Madhavan (dir.), Madhavan, Simran">Rocketry: The Nambi Effect</a>
#  <span class="secondaryInfo">(2022)</span>
#  </td>, <td class="titleColumn">
#        3.
#        <a href="/title/tt0093603/" title="Mani Ratnam (dir.), Kamal Haasan, Saranya Ponvannan">Nayakan</a>
#  <span class="secondaryInfo">(1987)</span>
#  </td>, <td class="titleColumn">
#        4.
#        <a href="/title/tt0079221/" title="Hrishikesh Mukherjee (dir.), Amol Palekar, Bindiya Goswami">Gol Maal</a>
#  <span class="secondaryInfo">(1979)</span>
#  </td>, <td class="titleColumn">
#        5.
#        <a href="/title/tt0367495/" title="Sundar C. (dir.), Kamal Haasan, Madhavan">Anbe Sivam</a>
# ...

# %% [markdown]
# Question 3 (10 points): Write python code to collect 1000 articles from Google Scholar (https://scholar.google.com/), Microsoft Academic (https://academic.microsoft.com/home), or CiteSeerX (https://citeseerx.ist.psu.edu/index), or Semantic Scholar (https://www.semanticscholar.org/), or ACM Digital Libraries (https://dl.acm.org/) with the keyword "information retrieval". The articles should be published in the last 10 years (2012-2022).
#
# The following information of the article needs to be collected:
#
# (1) Title
#
# (2) Venue/journal/conference being published
#
# (3) Year
#
# (4) Authors
#
# (5) Abstract

# %%
from google.colab import files
import io
art = files.upload()
# Out:
#      <input type="file" id="files-51fb54d5-b497-46c7-a043-286694607f01" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-51fb54d5-b497-46c7-a043-286694607f01">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
art=pd.read_csv('articles.csv')
years = []
print(art[["title","author_id","last_updated"]])
# Out:
#                                                    title         author_id  \
# 0                 5 Best Practices For Writing SQL Joins       priyankab14
# 1                           Foundation CSS Dropdown Menu  ishankhandelwals
# 2           Top 20 Excel Shortcuts That You Need To Know       priyankab14
# 3                              Servlet – Fetching Result   nishatiwari1719
# 4                                       Suffix Sum Array          rohit768
# ...                                                  ...               ...
# 34569              Data Structures | Queue | Question 11     GeeksforGeeks
# 34570        Data Structures | Binary Trees | Question 1     GeeksforGeeks
# 34571                           Amazon Interview | Set 9     GeeksforGeeks
# 34572  Python Program for Rat in a Maze | Backtracking-2     GeeksforGeeks
# 34573            Data Structures and Algorithms | Set 21     GeeksforGeeks
#
#        last_updated
# 0      21 Feb, 2022
# 1      20 Feb, 2022
# ...

# %% [markdown]
# Question 4 (10 points): Write python code to collect 1000 posts from Twitter, or Facebook, or Instagram. You can either use hashtags, keywords, user_name, user_id, or other information to collect the data.
#
# The following information needs to be collected:
#
# (1) User_name
#
# (2) Posted time
#
# (3) Text

# %%
import requests

url = "https://www.instagram.com/{}/?__a=1".format(username)
response = requests.get(url)
data = response.json()

posts = data['graphql']['user']['edge_owner_to_timeline_media']['edges']
post_count = 0

for post in posts:
    post_count += 1
    if post_count > 1000:
        break
    print(post['node']['shortcode'])

# %% [markdown]
# The above is the code to collect 1000 posts from instagram. In order to collect information from instagram we need access to instagram private API.
